# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://scraping-for-beginner.herokuapp.com/image'
res = requests.get(url)

# %%
res
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(res.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Webスクレイピング入門者のためのサイト</title>
# <!-- Compiled and minified CSS -->
# <link href="https://cdnjs.cloudflare.com/ajax/libs/materialize/1.0.0-rc.2/css/materialize.min.css" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"/>
#   <link href="static/assets/css/style.css" rel="stylesheet"/>
# <link href="static/assets/css/image.css" rel="stylesheet"/>
# </head>
# <body>
# <!-- Navbar -->
# <div class="navbar-fixed">
# <!-- Dropdown Structure -->
# <nav class="">
# <div class="nav-wrapper row">
# <div class="col s5 l4 offset-s1 offset-l1">
# /">Webスクレイピング入門</a>
# </div>
# <div class="col s5 l6">
# <ul class="right hide-on-med-and-down" id="nav-mobile">
# /login_page">ログイン</a></li>
# <li><a class="" href="/ranking/">ランキング</a></li>
# <li><a class="" href="/image">画像</a></li>
# <li><a class="" href="/udemy">Udemy</a></li>
# <li><a class="" href="https://scraping-for-beginner.readthedocs.io/" target="”_blank”">サンプルコード</a></li>
# </ul>
# </div>
# </div>
# </nav>
# </div>
# <div class="section"></div>
# <!-- Header -->
# <!-- <div class="header">
#   <img src="/static/assets/img/camera_icon.png" width="100px">
#   <h4 class="grey-text text-darken-3">写真一覧</h4>
# </div> -->
# <!-- Photo Grid -->
# <div class="container">
# <div class="row card">
# <div class="col s12 m6 l4"><img class="materialbox responsive-img card" src="/static/assets/img/img1.JPG"/></div>
# <div class="col s12 m6 l4"><img class="materialbox responsive-img card" src="/static/assets/img/img2.JPG"/></div>
# <div class="col s12 m6 l4"><img class="materialbox responsive-img card" src="/static/assets/img/img3.JPG"/></div>
# <div class="col s12 m6 l4"><img class="materialbox responsive-img card" src="/static/assets/img/img4.JPG"/></div>
# <div class="col s12 m6 l4"><img class="materialbox responsive-img card" src="/static/assets/img/img5.JPG"/></div>
# <div class="col s12 m6 l4"><img class="materialbox responsive-img card" src="/static/assets/img/img6.JPG"/></div>
# <div class="col s12 m6 l4"><img class="materialbox responsive-img card" src="/static/assets/img/img7.JPG"/></div>
# <div class="col s12 m6 l4"><img class="materialbox responsive-img card" src="/static/assets/img/img8.JPG"/></div>
# <div class="col s12 m6 l4"><img class="materialbox responsive-img card" src="/static/assets/img/img9.JPG"/></div>
# <div class="col s12 m6 l4"><img class="materialbox responsive-img card" src="/static/assets/img/img10.JPG"/></div>
# <div class="col s12 m6 l4"><img class="materialbox responsive-img card" src="/static/assets/img/img11.JPG"/></div>
# <div class="col s12 m6 l4"><img class="materialbox responsive-img card" src="/static/assets/img/img12.JPG"/></div>
# <div class="col s12 m6 l4"><img class="materialbox responsive-img card" src="/static/assets/img/img13.JPG"/></div>
# <div class="col s12 m6 l4"><img class="materialbox responsive-img card" src="/static/assets/img/img14.JPG"/></div>
# <div class="col s12 m6 l4"><img class="materialbox responsive-img card" src="/static/assets/img/img15.JPG"/></div>
# <div class="col s12 m6 l4"><img class="materialbox responsive-img card" src="/static/assets/img/img16.JPG"/></div>
# <div class="col s12 m6 l4"><img class="materialbox responsive-img card" src="/static/assets/img/img17.JPG"/></div>
# <div class="col s12 m6 l4"><img class="materialbox responsive-img card" src="/static/assets/img/img18.JPG"/></div>
# <div class="col s12 m6 l4"><img class="materialbox responsive-img card" src="/static/assets/img/img19.JPG"/></div>
# <div class="col s12 m6 l4"><img class="materialbox responsive-img card" src="/static/assets/img/img20.JPG"/></div>
# <div class="col s12 m6 l4"><img class="materialbox responsive-img card" src="/static/assets/img/img21.JPG"/></div>
# <div class="col s12 m6 l4"><img class="materialbox responsive-img card" src="/static/assets/img/img22.JPG"/></div>
# <div class="col s12 m6 l4"><img class="materialbox responsive-img card" src="/static/assets/img/img23.JPG"/></div>
# <div class="col s12 m6 l4"><img class="materialbox responsive-img card" src="/static/assets/img/img24.JPG"/></div>
# </div>
# </div>
# <div class="section"></div>
# <div class="section"></div>
# <!-- Compiled and minified JavaScript -->
# <script src="https://code.jquery.com/jquery-3.3.1.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/materialize/1.0.0-rc.2/js/materialize.min.js"></script>
# <script>
#   $(document).ready(function() {
#     $(".dropdown-trigger").dropdown();
#     $('.materialbox').materialbox();
#   });
# </script>
# </body>
# </html>

# %%
img_tag = soup.find('img')
img_tag['src']
# Out:
# '/static/assets/img/img1.JPG'

# %%
root_url = 'https://scraping-for-beginner.herokuapp.com'
img_url = root_url + img_tag['src']
img_url
# Out:
# 'https://scraping-for-beginner.herokuapp.com/static/assets/img/img1.JPG'

# %%
# !pip install Pillow
# Out:
# Requirement already satisfied: Pillow in c:\users\yuzo2\anaconda3\lib\site-packages (9.0.1)

# %%
from PIL import Image
import io

# %%
requests.get(img_url).content
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x01,\x01,\x00\x00\xff\xe1\x03(Exif\x00\x00MM\x00*\x00\x00\x00\x08\x00\t\x01\x0f\x00\x02\x00\x00\x00\x12\x00\x00\x00z\x01\x10\x00\x02\x00\x00\x00\x0c\x00\x00\x00\x8c\x01\x12\x00\x03\x00\x00\x00\x01\x00\x01\x00\x00\x01\x1a\x00\x05\x00\x00\x00\x01\x00\x00\x00\x98\x01\x1b\x00\x05\x00\x00\x00\x01\x00\x00\x00\xa0\x01(\x00\x03\x00\x00\x00\x01\x00\x02\x00\x00\x011\x00\x02\x00\x00\x00\n\x00\x00\x00\xa8\x012\x00\x02\x00\x00\x00\x14\x00\x00\x00\xb2\x87i\x00\x04\x00\x00\x00\x01\x00\x00\x00\xc6\x00\x00\x00\x00NIKON CORPORATION\x00NIKON D3200\x00\x00\x00\x01,\x00\x00\x00\x01\x00\x00\x01,\x00\x00\x00\x01Ver.1.03 \x002016:05:01 18:50:31\x00\x00&\x82\x9a\x00\x05\x00\x00\x00\x01\x00\x00\x02\x94\x82\x9d\x00\x05\x00\x00\x00\x01\x00\x00\x02\x9c\x88"\x00\x03\x00\x00\x00\x01\x00\x00\x00\x00\x88\'\x00\x03\x00\x00\x00\x01\x01\x90\x00\x00\x880\x00\x03\x00\x00\x00\x01\x00\x02\x00\x00\x90\x00\x00\x07\x00\x00\x00\x040230\x90\x03\x00\x02\x00\x00\x00\x14\x00\x00\x02\xa4\x90\x04\x00\x02\x00\x00\x00\x14\x00\x00\x02\xb8\x91\x01\x00\x07\x00\x00\x00\x04\x01\x02\x03\x00\x91\x02\x00\x05\x00\x00\x00\x01\x00\x00\x02\xcc\x92\x04\x00\n\x00\x00\x00\x01\x00\x00\x02\xd4\x92\x05\x00\x05\x00\x00\x00\x01\x00\x00\x02\xdc\x92\x07\x00\x03\x00\x00\x00\x01\x00\x05\x00\x00\x92\x08\x00\x03\x00\x00\x00\x01\x00\x00\x00\x00\x92\t\x00\x03\x00\x00\x00\x01\x00\x10\x00\x00\x92\n\x00\x05\x00\x00\x00\x01\x00\x00\x02\xe4\x92\x86\x00\x07\x00\x00\x00,\x00\x00\x02\xec\x92\x90\x00\x02\x00\x00\x00\x0350\x00\x00\x92\x91\x00\x02\x00\x00\x00\x0350\x00\x00\x92\x92\x00\x02\x00\x00\x00\x0350\x00\x00\xa0\x00\x00\x07\x00\x00\x00\x040100\t\x00\x03\x00\x00\x00\x01\x00\x00\x00\x00\xa4\n\x00\x03\x00\x00\x00\x01\x00\x00\x00\x00\xa4\x0c\x00\x03\x00\x00\x00\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x00\x00\x00d\x00\x00\x00\t\x00\x00\x00\x012016:05:01 18:50:31\x002016:05:01 18:50:31\x00\x00\x00\x00\x02\x00\x00\x00\x01\x00\x00\x00\x00\x00\x00\x00\x01\x00\x00\x00\x13\x00\x00\x00\x05\x00\x00\x00\x14\x00\x00\x00\x01ASCII\x00\x00\x00                                    \x00\x00\x00\x01\x00\x00\x00\x01\xff\xe1\x0b\x0fhttp://ns.adobe.com/xap/1.0/\x00<?xpacket begin="\xef\xbb\xbf" id="W5M0MpCehiHzreSzNTczkc9d"?> <x:xmpmeta xmlns:x="adobe:ns:meta/" x:xmptk="XMP Core 5.4.0"> <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"> <rdf:Description rdf:about="" xmlns:aux="http://ns.adobe.com/exif/1.0/aux/" xmlns:xmp="http://ns.adobe.com/xap/1.0/" xmlns:photoshop="http://ns.adobe.com/photoshop/1.0/" aux:SerialNumber="2223517" aux:FlashCompensation="0/1" aux:ImageNumber="2219" aux:LensID="-7331810358111462386" aux:LensInfo="18/1 55/1 7/2 28/5" aux:Lens="AF-S DX VR Zoom-Nikkor 18-55mm f/3.5-5.6G" xmp:ModifyDate="2016-05-01T18:50:31.50" xmp:CreateDate="2016-05-01T18:50:31.50" xmp:CreatorTool="Ver.1.03 " photoshop:DateCreated="2016-05-01T18:50:31.50"/> </rdf:RDF> </x:xmpmeta>                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...

# %%
img = Image.open(io.BytesIO(requests.get(img_url).content))
img.save('img/sample.png')

# %%
soup = BeautifulSoup(res.text, 'html.parser')
img_tag = soup.find('img')

root_url = 'https://scraping-for-beginner.herokuapp.com'
img_url = root_url + img_tag['src']

img = Image.open(io.BytesIO(requests.get(img_url).content))
img.save('img/sample.png')

# %%
img_tags = soup.find_all('img')
for i, img_tag in enumerate(img_tags):

    root_url = 'https://scraping-for-beginner.herokuapp.com'
    img_url = root_url + img_tag['src']

    img = Image.open(io.BytesIO(requests.get(img_url).content))
    img.save(f'img/{i}.png')
